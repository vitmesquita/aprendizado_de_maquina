# %%
import pandas as pd

# %%
import sys
sys.path.append('..')

# %%
from config import *

# %%
df = pd.read_csv('preprocessed.csv')

# %%
df
# Out:
#       Unnamed: 0  folio  marital  y_educa  gender  age  last_level_school  \
# 0              0      0      4.0      4.0       2   82                1.0
# 1              1      1      2.0      2.0       2   82                1.0
# 2              2      2      2.0      0.0       2   83                NaN
# 3              3      3      2.0      0.0       2   75                1.0
# 4              4      4      4.0      4.0       1   78                1.0
# ...          ...    ...      ...      ...     ...  ...                ...
# 7445        7445   7445      5.0      8.0       1   60                1.0
# 7446        7446   7446      0.0     10.0       2   60                1.0
# 7447        7447   7447      2.0     10.0       2   60                1.0
# 7448        7448   7448      2.0      5.0       2   60                1.0
# 7449        7449   7449      0.0     10.0       1   60                1.0
#
#       religion  n_children  takes_medicine  kind_health_ins  times_hospital  \
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
import plotly.express as px
fig = px.box(df,x='age_stop_working',y='functional_score')
fig.show()
# Out:
# <div>                            <div id="9af0e647-2f5a-4e95-bd7f-0348c649bfaf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9af0e647-2f5a-4e95-bd7f-0348c649bfaf")) {                    Plotly.newPlot(                        "9af0e647-2f5a-4e95-bd7f-0348c649bfaf",                        [{"alignmentgroup": "True", "hovertemplate": "age_stop_working=%{x}<br>functional_score=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": [56.0, 59.0, 74.0, 73.0, 62.0, 73.0, 57.0, 58.0, 65.0, null, 34.0, 48.0, 57.0, null, 26.0, 45.0, 61.0, 55.0, 35.0, 65.0, null, 65.0, 55.0, 50.0, 67.0, 65.0, 28.0, 68.0, 33.0, null, null, 58.0, null
# ...

# %%
fig = px.bar(df,x='age_stop_working',y='functional_score')
fig.show()
# Out:
# <div>                            <div id="8103c3f5-8309-4071-8ef5-77be0ade7b0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8103c3f5-8309-4071-8ef5-77be0ade7b0b")) {                    Plotly.newPlot(                        "8103c3f5-8309-4071-8ef5-77be0ade7b0b",                        [{"alignmentgroup": "True", "hovertemplate": "age_stop_working=%{x}<br>functional_score=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [56.0, 59.0, 74.0, 73.0, 62.0, 73.0, 57.0, 58.0, 65.0, null, 34.0, 48.0, 57.0, null, 26.0, 45.0, 61.0, 55.0, 35.0, 65.0, null, 65.0, 55.0, 50.0, 67.0, 65.0, 28.0, 68.0, 33.0, null, null, 58.0
# ...

# %%
df.groupby('kind_health_ins')['age'].mean()
# Out:
# kind_health_ins
# 0.0    71.845343
# 1.0    72.630571
# 2.0    71.378543
# 3.0    71.162246
# 4.0    71.838083
# Name: age, dtype: float64

# %%
df.groupby('takes_medicine')['age'].mean()
# Out:
# takes_medicine
# 0.0    71.157110
# 1.0    72.568735
# Name: age, dtype: float64

# %%
df.groupby('last_level_school')['n_children'].mean()
# Out:
# last_level_school
# 1.0    3.259761
# 2.0    3.408681
# 3.0    2.836420
# Name: n_children, dtype: float64
